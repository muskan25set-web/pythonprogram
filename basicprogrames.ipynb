# %% [markdown]
# Name = Muskan
#
# Roll no. = 250246
#
# Course = BCA 1st year
#
# Course code = CA23.136
#
# Purpose of the program is to perform basic python programes.

# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/muskan25set/pythonprogram/blob/main/notebooks/basicprogrames.ipynb)

# %% [markdown]
# Program to print a word.

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# Program to add two numbers.

# %%
a=int(input("Enter first number:"))
b=int(input("Enter second number:"))
c=a+b
print(c)
# Out:
# Enter first number:10
# Enter second number:3
# 13

# %% [markdown]
# Program to print a variable.

# %%
a="Muskan"
print(a)
# Out:
# Muskan

# %% [markdown]
# Program to add two strings.

# %%
a="8"
b="Muskan"
c=a+b
print(c)
# Out:
# 8Muskan

# %% [markdown]
# Program of converting int into string and add two strings

# %%
a=str(5)
b="Muskan"
c=a+b
print(c)
# Out:
# 5Muskan

# %% [markdown]
# Program of printing a string

# %%
"Hello World"
# Out:
# 'Hello World'

# %% [markdown]
# Program of division.

# %%
a = float(input("Enter first number: "))
b = float(input("Enter second number: "))

result = a / b

print("Division result is:", result)
# Out:
# Enter first number: 23
# Enter second number: 4
# Division result is: 5.75

# %% [markdown]
# Program to square a number.

# %%
num = int(input("Enter a number: "))

square = num * num

print("Square is:", square)
# Out:
# Enter a number: 23
# Square is: 529
